# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
from bs4 import BeautifulSoup
import requests
from collections import defaultdict
import json
import re

# %%
insta_url = 'https://www.instagram.com/nasa/'

insta_account = requests.get(test_insta)
insta_soup = BeautifulSoup(insta_account.text, 'lxml')

# %%
insta_soup
# Out:
# <!DOCTYPE html>
# <html class="no-js not-logged-in client-root" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>
# NASA (@nasa) • Instagram photos and videos
# </title>
# <meta content="noimageindex, noarchive" name="robots"/>
# <meta content="default" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="yes" name="mobile-web-app-capable"/>
# <meta content="#ffffff" name="theme-color"/>
# <meta content="width=device-width, initial-scale=1, minimum-scale=1, maximum-scale=1, viewport-fit=cover" id="viewport" name="viewport"/>
# <link href="/data/manifest.json" rel="manifest"/>
# <link as="style" crossorigin="anonymous" href="/static/bundles/metro/ConsumerUICommons.css/2c4063e449cd.css" rel="preload" type="text/css"/>
# <link as="style" crossorigin="anonymous" href="/static/bundles/metro/ConsumerAsyncCommons.css/8e4b0b707ace.css" rel="preload" type="text/css"/>
# ...

# %%
insta_headline = (insta_soup.find('link', attrs={'href': insta_url, 'rel':"canonical"})
 .nextSibling.nextSibling.get('content'))

insta_stats_pattern = '''(?P<n_followers>[0-9\.\,]*[a-z]*)\sFollowers\s(?P<n_following>[0-9\.]*)\sFollowing,\s(?P<n_posts>[0-9\.\,]*[a-z]*)\sPosts'''

re.compile(insta_stats_pattern, insta_headline)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-33e677857ff6> in <module>
# ----> 1 insta_headline = (insta_soup.find('link', attrs={'href': insta_url, 'rel':"canonical"})
#       2  .nextSibling.nextSibling.get('content'))
#       3
#       4 insta_stats_pattern = '''(?P<n_followers>[0-9\.\,]*[a-z]*)\sFollowers\s(?P<n_following>[0-9\.]*)\sFollowing,\s(?P<n_posts>[0-9\.\,]*[a-z]*)\sPosts'''
#       5
#
# NameError: name 'insta_soup' is not defined

# %%
import re

# %%
insta_headline = "49.6m Followers, 85 Following, 2,728 Posts - See Instagram photos and videos from NASA (@nasa)"

pattern = '(?P<n_followers>[0-9\.\,]*[a-z]*)\sFollowers\,\s(?P<n_following>[0-9\.]*)\sFollowing,\s(?P<n_posts>[0-9\.\,]*[a-z]*)\sPosts'

mat = re.match(pattern, insta_headline)
print(mat.group('n_followers'))
print(mat.group('n_following'))
print(mat.group('n_posts'))
# Out:
# 49.6m
# 85
# 2,728
